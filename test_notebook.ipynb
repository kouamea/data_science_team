# %%
import pandas as pd
dataset = 'C2022Q2R2'

dd = pd.read_gbq(f'''SELECT * from `{dataset}.ds_data_dictionary`''', project_id = "aou-res-curation-output-prod")
dd
# Out:
#       id               field_name   relevant_omop_table  \
# 0    528                    steps        steps_intraday
# 1    496                  version     cb_survey_version
# 2    190  cdm_source_abbreviation            cdm_source
# 3    197              cdm_version            cdm_source
# 4    228     concept_synonym_name       concept_synonym
# ..   ...                      ...                   ...
# 543  252          vocabulary_name            vocabulary
# 544  253     vocabulary_reference            vocabulary
# 545  254       vocabulary_version            vocabulary
# 546  274                   domain  cb_review_all_events
# 547  294                   domain  cb_search_all_events
#
#                                            description    field_type  \
# 0          The number of steps recorded within one day       numeric
# 1    Supports the seleciton of different COVID Part...   string(100)
# 2                   An abbreviation of the source name    string(25)
# ...
